# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MECE689_Superman/code
# !ls -la
# Out:
# /content/drive/MyDrive/MECE689_Superman/code
# total 460
# -rw------- 1 root root   2239 Sep 25 04:13 A2C_Attempt.ipynb
# -rw------- 1 root root 214592 Sep 25 14:23 dqn_baseline_google_colab.ipynb
# -rw------- 1 root root   9534 Sep 25 04:13 eval_baseline.ipynb
# drwx------ 2 root root   4096 Sep 25 04:13 .git
# -rw------- 1 root root     56 Sep 25 04:13 .gitignore
# -rw------- 1 root root  10317 Sep 25 04:13 PPO_Attempt.ipynb
# -rw------- 1 root root   2699 Sep 25 04:13 QRDQN_Attempt.ipynb
# -rw------- 1 root root   1827 Sep 25 04:13 README.md
# -rw------- 1 root root   5064 Sep 25 04:13 requirements.txt
# -rw------- 1 root root   2389 Sep 25 04:13 test_one.ipynb
# -rw------- 1 root root   6939 Sep 25 04:13 test_two.ipynb
# -rw------- 1 root root   2193 Sep 25 04:13 test_zero.ipynb
# -rw------- 1 root root  29641 Sep 25 04:13 train_baseline_action_mask.ipynb
# -rw------- 1 root root  18801 Sep 25 04:13 train_baseline_action_mask_vector_env.ipynb
# ...

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	dqn_baseline_google_colab.ipynb
# 	github_terminal.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git config --global user.email "loganwong52@gmail.com"
# !git config --global user.name "loganwong52"

# %%
# !git add .
# !git commit -m "Add 2 notebooks I made in Google Colab"

# !git push https://loganwong:YOUR_PERSONAL_ACCESS_TOKEN@github.com/YOUR_GITHUB_USERNAME/YOUR_REPO_NAME.git main
# Out:
# [main 44df5d3] Add 2 notebooks I made in Google Colab
#  2 files changed, 2 insertions(+)
#  create mode 100644 dqn_baseline_google_colab.ipynb
#  create mode 100644 github_terminal.ipynb
# fatal: could not read Username for 'https://github.com': No such device or address
