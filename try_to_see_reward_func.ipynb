# %%
import gymnasium as gym
import ale_py
import numpy as np
import time
from stable_baselines3 import DQN	
import matplotlib.pyplot as plt
from collections import deque

# Action masking
from gymnasium import ActionWrapper

# %%
class SupermanActionReducer(ActionWrapper):
    def __init__(self, env, allowed_actions=None):
        super().__init__(env)
        
        if allowed_actions is None:
            # Basic movement only: Cardinal directions & diagonal directions
            allowed_actions = [2,3,4,5, 6,7,8,9]
        
        self.allowed_actions = allowed_actions
        self.action_space = gym.spaces.Discrete(len(allowed_actions))
        
    def action(self, action):
        # Map the reduced action index back to the original action
        return self.allowed_actions[action]

# %%
# # ACTIONS
# 0: NOOP
# 1: FIRE

# 2: UP
# 3: RIGHT
# 4: LEFT
# 5: DOWN
# 6: UPRIGHT
# 7: UPLEFT
# 8: DOWNRIGHT
# 9: DOWNLEFT

# 10: UPFIRE
# 11: RIGHTFIRE
# 12: LEFTFIRE
# 13: DOWNFIRE
# 14: UPRIGHTFIRE
# 15: UPLEFTFIRE
# 16: DOWNRIGHTFIRE
# 17: DOWNLEFTFIRE

# %%
env = gym.make("ALE/Superman-v5", render_mode=None)
# env = SupermanActionReducer(env)

# %%
test_actions = [
    ("UP", 2),
    ("RIGHT", 3), 
    ("LEFT", 4), 
    ("DOWN", 5),


    ("UPRIGHT", 6),
    ("UPLEFT", 7),
    ("DOWNRIGHT", 8),
    ("DOWNLEFT", 9),
    
    ("UPFIRE", 10),
    ("RIGHTFIRE", 11),
    ("LEFTFIRE", 12),
    ("DOWNFIRE", 13),
    ("UPRIGHTFIRE", 14),
    ("UPLEFTFIRE", 15),
    ("DOWNRIGHTFIRE", 16),
    ("DOWNLEFTFIRE", 17)
]

# %%
# Test specific actions in specific states
for action_name, action in test_actions:
    obs, _ = env.reset()
    total_reward = 0
    for step in range(100):
        obs, reward, done, truncated, info = env.step(action)
        total_reward += reward
        if reward != 0:
            print(f"Action {action_name} got reward {reward} at step {step}")
        if done:
            break
    print(f"Action {action_name}: Total reward = {total_reward}")
# Out:
# Action UP: Total reward = 0.0
# Action RIGHT: Total reward = 0.0
# Action LEFT: Total reward = 0.0
# Action DOWN: Total reward = 0.0
# Action UPRIGHT: Total reward = 0.0
# Action UPLEFT: Total reward = 0.0
# Action DOWNRIGHT: Total reward = 0.0
# Action DOWNLEFT: Total reward = 0.0
# Action UPFIRE: Total reward = 0.0
# Action RIGHTFIRE: Total reward = 0.0
# Action LEFTFIRE: Total reward = 0.0
# Action DOWNFIRE: Total reward = 0.0
# Action UPRIGHTFIRE: Total reward = 0.0
# Action UPLEFTFIRE: Total reward = 0.0
# Action DOWNRIGHTFIRE: Total reward = 0.0
# Action DOWNLEFTFIRE: Total reward = 0.0

# %%
env = gym.make("ALE/Superman-v5", render_mode=None)
obs, _ = env.reset()

action_dict = {0: 'NOOP', 1: 'FIRE', 2: 'UP', 3: 'RIGHT', 4: 'LEFT', 5: 'DOWN', 6: 'UPRIGHT', 7: 'UPLEFT', 8: 'DOWNRIGHT', 9: 'DOWNLEFT', 10: 'UPFIRE', 11: 'RIGHTFIRE', 12: 'LEFTFIRE', 13: 'DOWNFIRE', 14: 'UPRIGHTFIRE', 15: 'UPLEFTFIRE', 16: 'DOWNRIGHTFIRE', 17: 'DOWNLEFTFIRE'}

# %%
for _ in range(1000):
    action = env.action_space.sample()
    action_name = action_dict[action]
    print(f"Action: {action_name}\n")
    obs, reward, done, truncated, info = env.step(action)
    
    # Check if score is available in info
    # print(obs)
    print(reward)
    # print(done)
    # print(truncated)
    print(info)
    # if 'score' in info:
        # print(f"Score: {info['score']}, Reward: {reward}")
    # else:
        # print("no score in info")
        
    if done:
        break
# Out:
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12004, 'frame_number': 12004}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12008, 'frame_number': 12008}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12012, 'frame_number': 12012}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12016, 'frame_number': 12016}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12020, 'frame_number': 12020}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12024, 'frame_number': 12024}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12028, 'frame_number': 12028}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12032, 'frame_number': 12032}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12036, 'frame_number': 12036}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12040, 'frame_number': 12040}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12044, 'frame_number': 12044}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12048, 'frame_number': 12048}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12052, 'frame_number': 12052}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12056, 'frame_number': 12056}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12060, 'frame_number': 12060}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12064, 'frame_number': 12064}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12068, 'frame_number': 12068}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12072, 'frame_number': 12072}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12076, 'frame_number': 12076}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12080, 'frame_number': 12080}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12084, 'frame_number': 12084}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12088, 'frame_number': 12088}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12092, 'frame_number': 12092}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12096, 'frame_number': 12096}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12100, 'frame_number': 12100}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12104, 'frame_number': 12104}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12108, 'frame_number': 12108}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12112, 'frame_number': 12112}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12116, 'frame_number': 12116}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12120, 'frame_number': 12120}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12124, 'frame_number': 12124}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12128, 'frame_number': 12128}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12132, 'frame_number': 12132}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12136, 'frame_number': 12136}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12140, 'frame_number': 12140}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12144, 'frame_number': 12144}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12148, 'frame_number': 12148}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12152, 'frame_number': 12152}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12156, 'frame_number': 12156}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12160, 'frame_number': 12160}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12164, 'frame_number': 12164}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12168, 'frame_number': 12168}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12172, 'frame_number': 12172}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12176, 'frame_number': 12176}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12180, 'frame_number': 12180}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12184, 'frame_number': 12184}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12188, 'frame_number': 12188}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12192, 'frame_number': 12192}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12196, 'frame_number': 12196}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12200, 'frame_number': 12200}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12204, 'frame_number': 12204}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12208, 'frame_number': 12208}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12212, 'frame_number': 12212}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12216, 'frame_number': 12216}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12220, 'frame_number': 12220}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12224, 'frame_number': 12224}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12228, 'frame_number': 12228}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12232, 'frame_number': 12232}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12236, 'frame_number': 12236}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12240, 'frame_number': 12240}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12244, 'frame_number': 12244}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12248, 'frame_number': 12248}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12252, 'frame_number': 12252}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12256, 'frame_number': 12256}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12260, 'frame_number': 12260}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12264, 'frame_number': 12264}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12268, 'frame_number': 12268}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12272, 'frame_number': 12272}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12276, 'frame_number': 12276}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12280, 'frame_number': 12280}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12284, 'frame_number': 12284}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12288, 'frame_number': 12288}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12292, 'frame_number': 12292}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12296, 'frame_number': 12296}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12300, 'frame_number': 12300}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12304, 'frame_number': 12304}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12308, 'frame_number': 12308}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12312, 'frame_number': 12312}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12316, 'frame_number': 12316}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12320, 'frame_number': 12320}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12324, 'frame_number': 12324}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12328, 'frame_number': 12328}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12332, 'frame_number': 12332}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12336, 'frame_number': 12336}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12340, 'frame_number': 12340}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12344, 'frame_number': 12344}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12348, 'frame_number': 12348}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12352, 'frame_number': 12352}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12356, 'frame_number': 12356}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12360, 'frame_number': 12360}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12364, 'frame_number': 12364}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12368, 'frame_number': 12368}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12372, 'frame_number': 12372}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12376, 'frame_number': 12376}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12380, 'frame_number': 12380}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12384, 'frame_number': 12384}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12388, 'frame_number': 12388}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12392, 'frame_number': 12392}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12396, 'frame_number': 12396}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12400, 'frame_number': 12400}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12404, 'frame_number': 12404}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12408, 'frame_number': 12408}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12412, 'frame_number': 12412}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12416, 'frame_number': 12416}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12420, 'frame_number': 12420}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12424, 'frame_number': 12424}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12428, 'frame_number': 12428}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12432, 'frame_number': 12432}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12436, 'frame_number': 12436}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12440, 'frame_number': 12440}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12444, 'frame_number': 12444}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12448, 'frame_number': 12448}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12452, 'frame_number': 12452}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12456, 'frame_number': 12456}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12460, 'frame_number': 12460}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12464, 'frame_number': 12464}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12468, 'frame_number': 12468}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12472, 'frame_number': 12472}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12476, 'frame_number': 12476}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12480, 'frame_number': 12480}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12484, 'frame_number': 12484}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12488, 'frame_number': 12488}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12492, 'frame_number': 12492}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12496, 'frame_number': 12496}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12500, 'frame_number': 12500}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12504, 'frame_number': 12504}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12508, 'frame_number': 12508}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12512, 'frame_number': 12512}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12516, 'frame_number': 12516}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12520, 'frame_number': 12520}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12524, 'frame_number': 12524}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12528, 'frame_number': 12528}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12532, 'frame_number': 12532}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12536, 'frame_number': 12536}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12540, 'frame_number': 12540}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12544, 'frame_number': 12544}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12548, 'frame_number': 12548}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12552, 'frame_number': 12552}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12556, 'frame_number': 12556}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12560, 'frame_number': 12560}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12564, 'frame_number': 12564}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12568, 'frame_number': 12568}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12572, 'frame_number': 12572}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12576, 'frame_number': 12576}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12580, 'frame_number': 12580}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12584, 'frame_number': 12584}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12588, 'frame_number': 12588}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12592, 'frame_number': 12592}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12596, 'frame_number': 12596}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12600, 'frame_number': 12600}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12604, 'frame_number': 12604}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12608, 'frame_number': 12608}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12612, 'frame_number': 12612}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12616, 'frame_number': 12616}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12620, 'frame_number': 12620}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12624, 'frame_number': 12624}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12628, 'frame_number': 12628}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12632, 'frame_number': 12632}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12636, 'frame_number': 12636}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12640, 'frame_number': 12640}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12644, 'frame_number': 12644}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12648, 'frame_number': 12648}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12652, 'frame_number': 12652}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12656, 'frame_number': 12656}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12660, 'frame_number': 12660}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12664, 'frame_number': 12664}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12668, 'frame_number': 12668}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12672, 'frame_number': 12672}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12676, 'frame_number': 12676}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12680, 'frame_number': 12680}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12684, 'frame_number': 12684}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12688, 'frame_number': 12688}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12692, 'frame_number': 12692}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12696, 'frame_number': 12696}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12700, 'frame_number': 12700}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12704, 'frame_number': 12704}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12708, 'frame_number': 12708}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12712, 'frame_number': 12712}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12716, 'frame_number': 12716}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12720, 'frame_number': 12720}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12724, 'frame_number': 12724}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12728, 'frame_number': 12728}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12732, 'frame_number': 12732}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12736, 'frame_number': 12736}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12740, 'frame_number': 12740}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12744, 'frame_number': 12744}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12748, 'frame_number': 12748}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12752, 'frame_number': 12752}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12756, 'frame_number': 12756}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12760, 'frame_number': 12760}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12764, 'frame_number': 12764}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12768, 'frame_number': 12768}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12772, 'frame_number': 12772}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12776, 'frame_number': 12776}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12780, 'frame_number': 12780}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12784, 'frame_number': 12784}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12788, 'frame_number': 12788}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12792, 'frame_number': 12792}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12796, 'frame_number': 12796}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12800, 'frame_number': 12800}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12804, 'frame_number': 12804}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12808, 'frame_number': 12808}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 12812, 'frame_number': 12812}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 

# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13684, 'frame_number': 13684}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13688, 'frame_number': 13688}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13692, 'frame_number': 13692}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13696, 'frame_number': 13696}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13700, 'frame_number': 13700}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13704, 'frame_number': 13704}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13708, 'frame_number': 13708}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13712, 'frame_number': 13712}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13716, 'frame_number': 13716}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13720, 'frame_number': 13720}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13724, 'frame_number': 13724}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13728, 'frame_number': 13728}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13732, 'frame_number': 13732}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13736, 'frame_number': 13736}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13740, 'frame_number': 13740}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13744, 'frame_number': 13744}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13748, 'frame_number': 13748}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13752, 'frame_number': 13752}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13756, 'frame_number': 13756}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13760, 'frame_number': 13760}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13764, 'frame_number': 13764}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13768, 'frame_number': 13768}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13772, 'frame_number': 13772}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13776, 'frame_number': 13776}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13780, 'frame_number': 13780}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13784, 'frame_number': 13784}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13788, 'frame_number': 13788}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13792, 'frame_number': 13792}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13796, 'frame_number': 13796}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13800, 'frame_number': 13800}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13804, 'frame_number': 13804}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13808, 'frame_number': 13808}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13812, 'frame_number': 13812}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13816, 'frame_number': 13816}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13820, 'frame_number': 13820}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13824, 'frame_number': 13824}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13828, 'frame_number': 13828}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13832, 'frame_number': 13832}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13836, 'frame_number': 13836}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13840, 'frame_number': 13840}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13844, 'frame_number': 13844}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13848, 'frame_number': 13848}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13852, 'frame_number': 13852}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13856, 'frame_number': 13856}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13860, 'frame_number': 13860}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13864, 'frame_number': 13864}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13868, 'frame_number': 13868}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13872, 'frame_number': 13872}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13876, 'frame_number': 13876}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13880, 'frame_number': 13880}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13884, 'frame_number': 13884}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13888, 'frame_number': 13888}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13892, 'frame_number': 13892}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13896, 'frame_number': 13896}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13900, 'frame_number': 13900}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13904, 'frame_number': 13904}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13908, 'frame_number': 13908}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13912, 'frame_number': 13912}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13916, 'frame_number': 13916}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13920, 'frame_number': 13920}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13924, 'frame_number': 13924}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13928, 'frame_number': 13928}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13932, 'frame_number': 13932}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13936, 'frame_number': 13936}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13940, 'frame_number': 13940}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13944, 'frame_number': 13944}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13948, 'frame_number': 13948}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13952, 'frame_number': 13952}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13956, 'frame_number': 13956}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13960, 'frame_number': 13960}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13964, 'frame_number': 13964}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13968, 'frame_number': 13968}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13972, 'frame_number': 13972}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13976, 'frame_number': 13976}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13980, 'frame_number': 13980}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13984, 'frame_number': 13984}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13988, 'frame_number': 13988}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13992, 'frame_number': 13992}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 13996, 'frame_number': 13996}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14000, 'frame_number': 14000}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14004, 'frame_number': 14004}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14008, 'frame_number': 14008}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14012, 'frame_number': 14012}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14016, 'frame_number': 14016}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14020, 'frame_number': 14020}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14024, 'frame_number': 14024}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14028, 'frame_number': 14028}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14032, 'frame_number': 14032}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14036, 'frame_number': 14036}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14040, 'frame_number': 14040}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14044, 'frame_number': 14044}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14048, 'frame_number': 14048}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14052, 'frame_number': 14052}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14056, 'frame_number': 14056}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14060, 'frame_number': 14060}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14064, 'frame_number': 14064}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14068, 'frame_number': 14068}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14072, 'frame_number': 14072}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14076, 'frame_number': 14076}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14080, 'frame_number': 14080}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14084, 'frame_number': 14084}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14088, 'frame_number': 14088}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14092, 'frame_number': 14092}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14096, 'frame_number': 14096}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14100, 'frame_number': 14100}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14104, 'frame_number': 14104}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14108, 'frame_number': 14108}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14112, 'frame_number': 14112}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14116, 'frame_number': 14116}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14120, 'frame_number': 14120}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14124, 'frame_number': 14124}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14128, 'frame_number': 14128}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14132, 'frame_number': 14132}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14136, 'frame_number': 14136}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14140, 'frame_number': 14140}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14144, 'frame_number': 14144}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14148, 'frame_number': 14148}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14152, 'frame_number': 14152}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14156, 'frame_number': 14156}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14160, 'frame_number': 14160}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14164, 'frame_number': 14164}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14168, 'frame_number': 14168}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14172, 'frame_number': 14172}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 14176, 'frame_number': 14176}
# Action: DOWNRIGHT
#
# 0.0
# ...
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15280, 'frame_number': 15280}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15284, 'frame_number': 15284}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15288, 'frame_number': 15288}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15292, 'frame_number': 15292}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15296, 'frame_number': 15296}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15300, 'frame_number': 15300}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15304, 'frame_number': 15304}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15308, 'frame_number': 15308}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15312, 'frame_number': 15312}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15316, 'frame_number': 15316}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15320, 'frame_number': 15320}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15324, 'frame_number': 15324}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15328, 'frame_number': 15328}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15332, 'frame_number': 15332}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15336, 'frame_number': 15336}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15340, 'frame_number': 15340}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15344, 'frame_number': 15344}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15348, 'frame_number': 15348}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15352, 'frame_number': 15352}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15356, 'frame_number': 15356}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15360, 'frame_number': 15360}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15364, 'frame_number': 15364}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15368, 'frame_number': 15368}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15372, 'frame_number': 15372}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15376, 'frame_number': 15376}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15380, 'frame_number': 15380}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15384, 'frame_number': 15384}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15388, 'frame_number': 15388}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15392, 'frame_number': 15392}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15396, 'frame_number': 15396}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15400, 'frame_number': 15400}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15404, 'frame_number': 15404}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15408, 'frame_number': 15408}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15412, 'frame_number': 15412}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15416, 'frame_number': 15416}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15420, 'frame_number': 15420}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15424, 'frame_number': 15424}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15428, 'frame_number': 15428}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15432, 'frame_number': 15432}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15436, 'frame_number': 15436}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15440, 'frame_number': 15440}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15444, 'frame_number': 15444}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15448, 'frame_number': 15448}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15452, 'frame_number': 15452}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15456, 'frame_number': 15456}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15460, 'frame_number': 15460}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15464, 'frame_number': 15464}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15468, 'frame_number': 15468}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15472, 'frame_number': 15472}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15476, 'frame_number': 15476}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15480, 'frame_number': 15480}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15484, 'frame_number': 15484}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15488, 'frame_number': 15488}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15492, 'frame_number': 15492}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15496, 'frame_number': 15496}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15500, 'frame_number': 15500}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15504, 'frame_number': 15504}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15508, 'frame_number': 15508}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15512, 'frame_number': 15512}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15516, 'frame_number': 15516}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15520, 'frame_number': 15520}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15524, 'frame_number': 15524}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15528, 'frame_number': 15528}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15532, 'frame_number': 15532}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15536, 'frame_number': 15536}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15540, 'frame_number': 15540}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15544, 'frame_number': 15544}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15548, 'frame_number': 15548}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15552, 'frame_number': 15552}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15556, 'frame_number': 15556}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15560, 'frame_number': 15560}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15564, 'frame_number': 15564}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15568, 'frame_number': 15568}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15572, 'frame_number': 15572}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15576, 'frame_number': 15576}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15580, 'frame_number': 15580}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15584, 'frame_number': 15584}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15588, 'frame_number': 15588}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15592, 'frame_number': 15592}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15596, 'frame_number': 15596}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15600, 'frame_number': 15600}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15604, 'frame_number': 15604}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15608, 'frame_number': 15608}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15612, 'frame_number': 15612}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15616, 'frame_number': 15616}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15620, 'frame_number': 15620}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15624, 'frame_number': 15624}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15628, 'frame_number': 15628}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15632, 'frame_number': 15632}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15636, 'frame_number': 15636}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15640, 'frame_number': 15640}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15644, 'frame_number': 15644}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15648, 'frame_number': 15648}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15652, 'frame_number': 15652}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15656, 'frame_number': 15656}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15660, 'frame_number': 15660}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15664, 'frame_number': 15664}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15668, 'frame_number': 15668}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15672, 'frame_number': 15672}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15676, 'frame_number': 15676}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15680, 'frame_number': 15680}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15684, 'frame_number': 15684}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15688, 'frame_number': 15688}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15692, 'frame_number': 15692}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15696, 'frame_number': 15696}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15700, 'frame_number': 15700}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15704, 'frame_number': 15704}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15708, 'frame_number': 15708}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15712, 'frame_number': 15712}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15716, 'frame_number': 15716}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15720, 'frame_number': 15720}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15724, 'frame_number': 15724}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15728, 'frame_number': 15728}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15732, 'frame_number': 15732}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15736, 'frame_number': 15736}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15740, 'frame_number': 15740}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15744, 'frame_number': 15744}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15748, 'frame_number': 15748}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15752, 'frame_number': 15752}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15756, 'frame_number': 15756}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15760, 'frame_number': 15760}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15764, 'frame_number': 15764}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15768, 'frame_number': 15768}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15772, 'frame_number': 15772}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15776, 'frame_number': 15776}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15780, 'frame_number': 15780}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15784, 'frame_number': 15784}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15788, 'frame_number': 15788}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15792, 'frame_number': 15792}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15796, 'frame_number': 15796}
# Action: RIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15800, 'frame_number': 15800}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15804, 'frame_number': 15804}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15808, 'frame_number': 15808}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15812, 'frame_number': 15812}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15816, 'frame_number': 15816}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15820, 'frame_number': 15820}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15824, 'frame_number': 15824}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15828, 'frame_number': 15828}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15832, 'frame_number': 15832}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15836, 'frame_number': 15836}
# Action: UPFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15840, 'frame_number': 15840}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15844, 'frame_number': 15844}
# Action: DOWN
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15848, 'frame_number': 15848}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15852, 'frame_number': 15852}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15856, 'frame_number': 15856}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15860, 'frame_number': 15860}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15864, 'frame_number': 15864}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15868, 'frame_number': 15868}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15872, 'frame_number': 15872}
# Action: UPRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15876, 'frame_number': 15876}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15880, 'frame_number': 15880}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15884, 'frame_number': 15884}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15888, 'frame_number': 15888}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15892, 'frame_number': 15892}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15896, 'frame_number': 15896}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15900, 'frame_number': 15900}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15904, 'frame_number': 15904}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15908, 'frame_number': 15908}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15912, 'frame_number': 15912}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15916, 'frame_number': 15916}
# Action: LEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15920, 'frame_number': 15920}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15924, 'frame_number': 15924}
# Action: UPLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15928, 'frame_number': 15928}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15932, 'frame_number': 15932}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15936, 'frame_number': 15936}
# Action: FIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15940, 'frame_number': 15940}
# Action: NOOP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15944, 'frame_number': 15944}
# Action: DOWNRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15948, 'frame_number': 15948}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15952, 'frame_number': 15952}
# Action: DOWNFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15956, 'frame_number': 15956}
# Action: UPLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15960, 'frame_number': 15960}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15964, 'frame_number': 15964}
# Action: RIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15968, 'frame_number': 15968}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15972, 'frame_number': 15972}
# Action: UP
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15976, 'frame_number': 15976}
# Action: LEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15980, 'frame_number': 15980}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15984, 'frame_number': 15984}
# Action: UPRIGHTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15988, 'frame_number': 15988}
# Action: DOWNLEFTFIRE
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15992, 'frame_number': 15992}
# Action: DOWNLEFT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 15996, 'frame_number': 15996}
# Action: DOWNRIGHT
#
# 0.0
# {'lives': 1, 'episode_frame_number': 16000, 'frame_number': 16000}

# %%
# Likely Positive Rewards:
# Points for capturing criminals
# Points for repairing the bridge
# Large reward for completing the game

# Likely Negative Rewards:
# Points for touching kryptonite
