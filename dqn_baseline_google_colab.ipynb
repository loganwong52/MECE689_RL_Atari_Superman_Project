# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# %cd /content/drive/MyDrive/MECE689_Superman
# !ls -la
# Out:
# /content/drive/MyDrive/MECE689_Superman
# total 20
# drwx------ 2 root root 4096 Sep 25 04:10 checkpoints
# drwx------ 2 root root 4096 Sep 25 04:10 code
# drwx------ 2 root root 4096 Sep 25 04:10 logs
# drwx------ 2 root root 4096 Sep 25 04:10 models
# drwx------ 2 root root 4096 Sep 25 04:10 results

# %%
# !pip install stable-baselines3
# !pip install sb3_contrib
# !pip install "gymnasium==0.28.1"
# !pip install "gymnasium[atari,accept-rom-license]"
# !pip install ale-py

# !pip install stable-baselines3 gymnasium[atari,accept-rom-license] ale-py
# Out:
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.12/dist-packages (2.7.0)
# Requirement already satisfied: ale-py in /usr/local/lib/python3.12/dist-packages (0.11.2)
# Requirement already satisfied: gymnasium[accept-rom-license,atari] in /usr/local/lib/python3.12/dist-packages (0.28.1)
# Collecting gymnasium<1.3.0,>=0.29.1 (from stable-baselines3)
#   Using cached gymnasium-1.2.1-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.8.0+cu126)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# INFO: pip is looking at multiple versions of gymnasium[accept-rom-license,atari] to determine which version is compatible with other requirements. This could take a while.
# WARNING: gymnasium 1.2.1 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[accept-rom-license,atari]) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.19.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Using cached gymnasium-1.2.1-py3-none-any.whl (951 kB)
# Installing collected packages: gymnasium
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 0.28.1
#     Uninstalling gymnasium-0.28.1:
#       Successfully uninstalled gymnasium-0.28.1
# Successfully installed gymnasium-1.2.1

# %%
import torch
import gymnasium as gym
import stable_baselines3
from ale_py import ALEInterface

print("GPU available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

print("All imports working")
# Out:
# GPU available: True
# GPU: Tesla T4
# All imports working

# %%
import gymnasium as gym
import ale_py
import numpy as np
from stable_baselines3 import DQN
import matplotlib.pyplot as plt
from collections import deque
import torch

# For debugging
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.callbacks import BaseCallback
import time

# Action masking
# from gymnasium import ActionWrapper

# Vector environment
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack, VecEnvWrapper

# %%
# # SIMPLE TEST
# env = gym.make("ALE/Superman-v5", render_mode=None)

# action_space = env.action_space
# obs_space = env.observation_space
# print("Action space:", action_space)
# print("Number of actions:", action_space.n)
# action_meanings = env.unwrapped.get_action_meanings()
# print("Action meanings:", action_meanings)
# print("\nObservation space:", obs_space)

# obs, _ = env.reset()
# print("Observation shape:", obs.shape)
# env.close()

# Action meanings: ['NOOP', 'FIRE', 'UP', 'RIGHT', 'LEFT', 'DOWN', 'UPRIGHT', 'UPLEFT', 'DOWNRIGHT', 'DOWNLEFT', 'UPFIRE', 'RIGHTFIRE', 'LEFTFIRE', 'DOWNFIRE', 'UPRIGHTFIRE', 'UPLEFTFIRE', 'DOWNRIGHTFIRE', 'DOWNLEFTFIRE']

# {0: 'NOOP', 1: 'FIRE', 2: 'UP', 3: 'RIGHT', 4: 'LEFT', 5: 'DOWN', 6: 'UPRIGHT', 7: 'UPLEFT', 8: 'DOWNRIGHT', 9: 'DOWNLEFT', 10: 'UPFIRE', 11: 'RIGHTFIRE', 12: 'LEFTFIRE', 13: 'DOWNFIRE', 14: 'UPRIGHTFIRE', 15: 'UPLEFTFIRE', 16: 'DOWNRIGHTFIRE', 17: 'DOWNLEFTFIRE'}

# # ACTIONS
# 0: NOOP
# 1: FIRE

# 2: UP
# 3: RIGHT
# 4: LEFT
# 5: DOWN
# 6: UPRIGHT
# 7: UPLEFT
# 8: DOWNRIGHT
# 9: DOWNLEFT

# 10: UPFIRE
# 11: RIGHTFIRE
# 12: LEFTFIRE
# 13: DOWNFIRE

# 14: UPRIGHTFIRE
# 15: UPLEFTFIRE
# 16: DOWNRIGHTFIRE
# 17: DOWNLEFTFIRE

# %%
def convert(seconds):
    seconds = seconds % (24 * 3600)
    hour = seconds // 3600
    seconds %= 3600
    minutes = seconds // 60
    seconds %= 60

    return "%d:%02d:%02d" % (hour, minutes, seconds)

# %%
class SupermanActionReducer(VecEnvWrapper):
    def __init__(self, venv):
        super().__init__(venv)

        # Basic movement only: Cardinal directions & diagonal directions
        self.allowed_actions = [2,3,4,5, 6,7,8,9]

        self.action_space = gym.spaces.Discrete(len(self.allowed_actions))

    def step(self, actions):
        # Map reduced actions back to original actions
        original_actions = np.array([self.allowed_actions[a] for a in actions])
        return self.venv.step(original_actions)

    def step_wait(self):
        # This method is required
        return self.venv.step_wait()

    def reset(self):
        return self.venv.reset()

# %% [markdown]
# CREATE ENVIRONMENT

# %%
# Use make_atari_env, then apply your vectorized wrapper
env = make_atari_env("ALE/Superman-v5", n_envs=4, seed=0)
# Action masking
env = SupermanActionReducer(env)
env = VecFrameStack(env, n_stack=4)

# %%
# # Confirm number of possible actions is smaller now
# print(f"Original action space: {make_atari_env('ALE/Superman-v5', n_envs=1).action_space}")
# print(f"Reduced action space: {env.action_space}")
# Out:
# Original action space: Discrete(18)
# Reduced action space: Discrete(8)

# %%
# Policy: I tell it to use a CNN
# env: Pass in the environment
# Learing rat: Alpha = 0.0001
model = DQN(
    policy="CnnPolicy",
    env=env,
    learning_rate= 0.0001,
    buffer_size=100000,
    batch_size=32,
    target_update_interval=1000,
    verbose=1,
    device="cuda"
)

print("DQN model created successfully!")
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# DQN model created successfully!

# %%
# Save every 500K steps so you never lose more than 30 minutes
checkpoint_callback = CheckpointCallback(
    save_freq=500000,
    save_path="/content/drive/MyDrive/MECE689_Superman/checkpoints",
    name_prefix="dqn_baseline_10M"
)

total_timesteps = 10000000    # 10M
# total_timesteps =  2000000    # 2M
# total_timesteps =  1000000    # 1M
# total_timesteps =   100000    # 100K
# total_timesteps =    10000    # 10K
# total_timesteps =     5000    # 5K

# Time how long it takes
print("Training phase started.")
start_time = time.time()
# model.learn(total_timesteps=total_timesteps)
model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback)

end_time = time.time()
print("Training phase completed!")

# Calculate run time
training_duration = end_time - start_time
time_in_minutes_and_seconds = convert(training_duration)
print(f"Time taken: {time_in_minutes_and_seconds}")
print(f"Speed: {total_timesteps/training_duration:.2f} steps/second")
# Out:
# Streaming output truncated to the last 5000 lines.
# |    n_updates        | 62384    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 348      |
# |    time_elapsed     | 2943     |
# |    total_timesteps  | 1025220  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.98e-09 |
# |    n_updates        | 64070    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 347      |
# |    time_elapsed     | 3024     |
# |    total_timesteps  | 1052192  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.01e-10 |
# |    n_updates        | 65755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 347      |
# |    time_elapsed     | 3105     |
# |    total_timesteps  | 1079172  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.21e-10 |
# |    n_updates        | 67442    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 346      |
# |    time_elapsed     | 3188     |
# |    total_timesteps  | 1106156  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.74e-08 |
# |    n_updates        | 69128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 346      |
# |    time_elapsed     | 3269     |
# |    total_timesteps  | 1133124  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.37e-10 |
# |    n_updates        | 70814    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 346      |
# |    time_elapsed     | 3352     |
# |    total_timesteps  | 1160112  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.22e-10 |
# |    n_updates        | 72500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 345      |
# |    time_elapsed     | 3434     |
# |    total_timesteps  | 1187080  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.71e-09 |
# |    n_updates        | 74186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 345      |
# |    time_elapsed     | 3513     |
# |    total_timesteps  | 1214060  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.26e-09 |
# |    n_updates        | 75872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 345      |
# |    time_elapsed     | 3595     |
# |    total_timesteps  | 1241052  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.53e-11 |
# |    n_updates        | 77559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 344      |
# |    time_elapsed     | 3676     |
# |    total_timesteps  | 1268020  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.39e-11 |
# |    n_updates        | 79245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 344      |
# |    time_elapsed     | 3757     |
# |    total_timesteps  | 1295000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.79e-11 |
# |    n_updates        | 80931    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 344      |
# |    time_elapsed     | 3838     |
# |    total_timesteps  | 1321984  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.6e-10  |
# |    n_updates        | 82617    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 344      |
# |    time_elapsed     | 3920     |
# |    total_timesteps  | 1348972  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.88e-11 |
# |    n_updates        | 84304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 343      |
# |    time_elapsed     | 4001     |
# |    total_timesteps  | 1375936  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.76e-11 |
# |    n_updates        | 85989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 343      |
# |    time_elapsed     | 4082     |
# |    total_timesteps  | 1402924  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.21e-09 |
# |    n_updates        | 87676    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 343      |
# |    time_elapsed     | 4164     |
# |    total_timesteps  | 1429896  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.85e-10 |
# |    n_updates        | 89362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 343      |
# |    time_elapsed     | 4245     |
# |    total_timesteps  | 1456880  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.57e-11 |
# |    n_updates        | 91048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 342      |
# |    time_elapsed     | 4327     |
# |    total_timesteps  | 1483856  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.23e-11 |
# |    n_updates        | 92734    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 342      |
# |    time_elapsed     | 4410     |
# |    total_timesteps  | 1510820  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.04e-10 |
# |    n_updates        | 94420    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 342      |
# |    time_elapsed     | 4491     |
# |    total_timesteps  | 1537808  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.36e-10 |
# |    n_updates        | 96106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 342      |
# |    time_elapsed     | 4574     |
# |    total_timesteps  | 1564800  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.61e-10 |
# |    n_updates        | 97793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 341      |
# |    time_elapsed     | 4656     |
# |    total_timesteps  | 1591792  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.99e-10 |
# |    n_updates        | 99480    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 341      |
# |    time_elapsed     | 4738     |
# |    total_timesteps  | 1618784  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.26e-11 |
# |    n_updates        | 101167   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 341      |
# |    time_elapsed     | 4821     |
# |    total_timesteps  | 1645760  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.54e-10 |
# |    n_updates        | 102853   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 340      |
# |    time_elapsed     | 4905     |
# |    total_timesteps  | 1672728  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.42e-10 |
# |    n_updates        | 104539   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 340      |
# |    time_elapsed     | 4990     |
# |    total_timesteps  | 1699708  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.01e-11 |
# |    n_updates        | 106225   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 340      |
# |    time_elapsed     | 5073     |
# |    total_timesteps  | 1726692  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02e-10 |
# |    n_updates        | 107912   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 340      |
# |    time_elapsed     | 5156     |
# |    total_timesteps  | 1753668  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.47e-09 |
# |    n_updates        | 109598   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 339      |
# |    time_elapsed     | 5239     |
# |    total_timesteps  | 1780640  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.81e-10 |
# |    n_updates        | 111283   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 339      |
# |    time_elapsed     | 5321     |
# |    total_timesteps  | 1807608  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.61e-11 |
# |    n_updates        | 112969   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 339      |
# |    time_elapsed     | 5404     |
# |    total_timesteps  | 1834600  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.69e-11 |
# |    n_updates        | 114656   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 339      |
# |    time_elapsed     | 5487     |
# |    total_timesteps  | 1861568  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.07e-10 |
# |    n_updates        | 116341   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 339      |
# |    time_elapsed     | 5569     |
# |    total_timesteps  | 1888548  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.55e-11 |
# |    n_updates        | 118028   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 338      |
# |    time_elapsed     | 5650     |
# |    total_timesteps  | 1915516  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.17e-11 |
# |    n_updates        | 119713   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 338      |
# |    time_elapsed     | 5732     |
# |    total_timesteps  | 1942480  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.15e-11 |
# |    n_updates        | 121398   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 338      |
# |    time_elapsed     | 5814     |
# |    total_timesteps  | 1969464  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.47e-11 |
# |    n_updates        | 123085   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 338      |
# |    time_elapsed     | 5895     |
# |    total_timesteps  | 1996428  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.15e-10 |
# |    n_updates        | 124770   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 338      |
# |    time_elapsed     | 5977     |
# |    total_timesteps  | 2023408  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.19e-10 |
# |    n_updates        | 126456   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 338      |
# |    time_elapsed     | 6059     |
# |    total_timesteps  | 2050400  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.39e-11 |
# |    n_updates        | 128143   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 338      |
# |    time_elapsed     | 6141     |
# |    total_timesteps  | 2077372  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2e-10  |
# |    n_updates        | 129829   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 338      |
# |    time_elapsed     | 6222     |
# |    total_timesteps  | 2104348  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.6e-10  |
# |    n_updates        | 131515   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 338      |
# |    time_elapsed     | 6305     |
# |    total_timesteps  | 2131324  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.95e-10 |
# |    n_updates        | 133201   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 337      |
# |    time_elapsed     | 6388     |
# |    total_timesteps  | 2158304  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.53e-11 |
# |    n_updates        | 134887   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 337      |
# |    time_elapsed     | 6471     |
# |    total_timesteps  | 2185268  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21e-10 |
# |    n_updates        | 136573   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 337      |
# |    time_elapsed     | 6555     |
# |    total_timesteps  | 2212232  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.74e-11 |
# |    n_updates        | 138258   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 337      |
# |    time_elapsed     | 6637     |
# |    total_timesteps  | 2239212  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.15e-10 |
# |    n_updates        | 139944   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 337      |
# |    time_elapsed     | 6719     |
# |    total_timesteps  | 2266188  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.24e-10 |
# |    n_updates        | 141630   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 337      |
# |    time_elapsed     | 6799     |
# |    total_timesteps  | 2293176  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.86e-10 |
# |    n_updates        | 143317   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 337      |
# |    time_elapsed     | 6879     |
# |    total_timesteps  | 2320160  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.9e-10  |
# |    n_updates        | 145003   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 337      |
# |    time_elapsed     | 6958     |
# |    total_timesteps  | 2347136  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.92e-09 |
# |    n_updates        | 146689   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 337      |
# |    time_elapsed     | 7039     |
# |    total_timesteps  | 2374100  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.76e-10 |
# |    n_updates        | 148375   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 337      |
# |    time_elapsed     | 7121     |
# |    total_timesteps  | 2401084  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3e-10  |
# |    n_updates        | 150061   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 337      |
# |    time_elapsed     | 7201     |
# |    total_timesteps  | 2428056  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.78e-11 |
# |    n_updates        | 151747   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 337      |
# |    time_elapsed     | 7280     |
# |    total_timesteps  | 2455032  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45e-10 |
# |    n_updates        | 153433   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 337      |
# |    time_elapsed     | 7359     |
# |    total_timesteps  | 2482016  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62e-10 |
# |    n_updates        | 155119   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 337      |
# |    time_elapsed     | 7440     |
# |    total_timesteps  | 2508980  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.41e-10 |
# |    n_updates        | 156805   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 337      |
# |    time_elapsed     | 7521     |
# |    total_timesteps  | 2535972  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.26e-11 |
# |    n_updates        | 158492   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 337      |
# |    time_elapsed     | 7600     |
# |    total_timesteps  | 2562944  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.57e-10 |
# |    n_updates        | 160177   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 337      |
# |    time_elapsed     | 7681     |
# |    total_timesteps  | 2589924  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.98e-11 |
# |    n_updates        | 161864   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 337      |
# |    time_elapsed     | 7760     |
# |    total_timesteps  | 2616912  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.95e-10 |
# |    n_updates        | 163550   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 337      |
# |    time_elapsed     | 7838     |
# |    total_timesteps  | 2643876  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.41e-10 |
# |    n_updates        | 165236   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 337      |
# |    time_elapsed     | 7918     |
# |    total_timesteps  | 2670848  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.36e-11 |
# |    n_updates        | 166921   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 337      |
# |    time_elapsed     | 7998     |
# |    total_timesteps  | 2697836  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.4e-10  |
# |    n_updates        | 168608   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 337      |
# |    time_elapsed     | 8077     |
# |    total_timesteps  | 2724816  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.47e-10 |
# |    n_updates        | 170294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 337      |
# |    time_elapsed     | 8156     |
# |    total_timesteps  | 2751808  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.06e-10 |
# |    n_updates        | 171981   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 337      |
# |    time_elapsed     | 8236     |
# |    total_timesteps  | 2778800  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01e-10 |
# |    n_updates        | 173668   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 337      |
# |    time_elapsed     | 8315     |
# |    total_timesteps  | 2805768  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.14e-11 |
# |    n_updates        | 175354   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 337      |
# |    time_elapsed     | 8393     |
# |    total_timesteps  | 2832752  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.78e-10 |
# |    n_updates        | 177040   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 337      |
# |    time_elapsed     | 8471     |
# |    total_timesteps  | 2859740  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.29e-09 |
# |    n_updates        | 178727   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 337      |
# |    time_elapsed     | 8550     |
# |    total_timesteps  | 2886716  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.15e-10 |
# |    n_updates        | 180413   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 337      |
# |    time_elapsed     | 8629     |
# |    total_timesteps  | 2913692  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.33e-11 |
# |    n_updates        | 182099   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 337      |
# |    time_elapsed     | 8707     |
# |    total_timesteps  | 2940684  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.12e-11 |
# |    n_updates        | 183786   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 337      |
# |    time_elapsed     | 8785     |
# |    total_timesteps  | 2967660  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.38e-10 |
# |    n_updates        | 185472   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 337      |
# |    time_elapsed     | 8863     |
# |    total_timesteps  | 2994652  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.71e-10 |
# |    n_updates        | 187159   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 337      |
# |    time_elapsed     | 8940     |
# |    total_timesteps  | 3021632  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.41e-11 |
# |    n_updates        | 188845   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 338      |
# |    time_elapsed     | 9018     |
# |    total_timesteps  | 3048600  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03e-10 |
# |    n_updates        | 190531   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 338      |
# |    time_elapsed     | 9096     |
# |    total_timesteps  | 3075584  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.56e-10 |
# |    n_updates        | 192217   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 338      |
# |    time_elapsed     | 9174     |
# |    total_timesteps  | 3102572  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.43e-11 |
# |    n_updates        | 193904   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 338      |
# |    time_elapsed     | 9251     |
# |    total_timesteps  | 3129548  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.3e-11  |
# |    n_updates        | 195590   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 338      |
# |    time_elapsed     | 9329     |
# |    total_timesteps  | 3156540  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.41e-11 |
# |    n_updates        | 197277   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 338      |
# |    time_elapsed     | 9406     |
# |    total_timesteps  | 3183524  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.8e-09  |
# |    n_updates        | 198964   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 338      |
# |    time_elapsed     | 9483     |
# |    total_timesteps  | 3210500  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.7e-10  |
# |    n_updates        | 200650   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 338      |
# |    time_elapsed     | 9561     |
# |    total_timesteps  | 3237480  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.08e-10 |
# |    n_updates        | 202336   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 338      |
# |    time_elapsed     | 9638     |
# |    total_timesteps  | 3264444  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.56e-11 |
# |    n_updates        | 204021   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 338      |
# |    time_elapsed     | 9717     |
# |    total_timesteps  | 3291436  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.81e-11 |
# |    n_updates        | 205708   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 338      |
# |    time_elapsed     | 9796     |
# |    total_timesteps  | 3318412  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.93e-10 |
# |    n_updates        | 207394   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 338      |
# |    time_elapsed     | 9874     |
# |    total_timesteps  | 3345380  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.95e-11 |
# |    n_updates        | 209080   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 338      |
# |    time_elapsed     | 9953     |
# |    total_timesteps  | 3372348  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.21e-10 |
# |    n_updates        | 210765   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 338      |
# |    time_elapsed     | 10032    |
# |    total_timesteps  | 3399324  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.02e-11 |
# |    n_updates        | 212451   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 338      |
# |    time_elapsed     | 10110    |
# |    total_timesteps  | 3426300  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.78e-10 |
# |    n_updates        | 214137   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 338      |
# |    time_elapsed     | 10188    |
# |    total_timesteps  | 3453272  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03e-10 |
# |    n_updates        | 215823   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.55e-10 |
# |    n_updates        | 573283   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1364     |
# |    fps              | 339      |
# |    time_elapsed     | 27105    |
# |    total_timesteps  | 9199608  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.95e-11 |
# |    n_updates        | 574969   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1368     |
# |    fps              | 339      |
# |    time_elapsed     | 27186    |
# |    total_timesteps  | 9226580  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.44e-11 |
# |    n_updates        | 576655   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1372     |
# |    fps              | 339      |
# |    time_elapsed     | 27267    |
# |    total_timesteps  | 9253560  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.9e-10  |
# |    n_updates        | 578341   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1376     |
# |    fps              | 339      |
# |    time_elapsed     | 27347    |
# |    total_timesteps  | 9280532  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.36e-12 |
# |    n_updates        | 580027   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1380     |
# |    fps              | 339      |
# |    time_elapsed     | 27426    |
# |    total_timesteps  | 9307504  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.56e-11 |
# |    n_updates        | 581712   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1384     |
# |    fps              | 339      |
# |    time_elapsed     | 27505    |
# |    total_timesteps  | 9334476  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.94e-11 |
# |    n_updates        | 583398   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1388     |
# |    fps              | 339      |
# |    time_elapsed     | 27584    |
# |    total_timesteps  | 9361464  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.45e-11 |
# |    n_updates        | 585085   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1392     |
# |    fps              | 339      |
# |    time_elapsed     | 27663    |
# |    total_timesteps  | 9388456  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.18e-11 |
# |    n_updates        | 586772   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1396     |
# |    fps              | 339      |
# |    time_elapsed     | 27743    |
# |    total_timesteps  | 9415432  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08e-11 |
# |    n_updates        | 588458   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 339      |
# |    time_elapsed     | 27823    |
# |    total_timesteps  | 9442408  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.56e-11 |
# |    n_updates        | 590144   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1404     |
# |    fps              | 339      |
# |    time_elapsed     | 27902    |
# |    total_timesteps  | 9469384  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.87e-11 |
# |    n_updates        | 591830   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1408     |
# |    fps              | 339      |
# |    time_elapsed     | 27983    |
# |    total_timesteps  | 9496360  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.18e-10 |
# |    n_updates        | 593516   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1412     |
# |    fps              | 339      |
# |    time_elapsed     | 28063    |
# |    total_timesteps  | 9523336  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.3e-11  |
# |    n_updates        | 595202   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1416     |
# |    fps              | 339      |
# |    time_elapsed     | 28144    |
# |    total_timesteps  | 9550320  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.96e-10 |
# |    n_updates        | 596888   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1420     |
# |    fps              | 339      |
# |    time_elapsed     | 28225    |
# |    total_timesteps  | 9577288  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.16e-11 |
# |    n_updates        | 598574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1424     |
# |    fps              | 339      |
# |    time_elapsed     | 28305    |
# |    total_timesteps  | 9604268  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.51e-11 |
# |    n_updates        | 600260   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1428     |
# |    fps              | 339      |
# |    time_elapsed     | 28386    |
# |    total_timesteps  | 9631236  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.69e-11 |
# |    n_updates        | 601946   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1432     |
# |    fps              | 339      |
# |    time_elapsed     | 28468    |
# |    total_timesteps  | 9658212  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.58e-11 |
# |    n_updates        | 603632   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1436     |
# |    fps              | 339      |
# |    time_elapsed     | 28548    |
# |    total_timesteps  | 9685188  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.98e-10 |
# |    n_updates        | 605318   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1440     |
# |    fps              | 339      |
# |    time_elapsed     | 28628    |
# |    total_timesteps  | 9712168  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.68e-12 |
# |    n_updates        | 607004   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1444     |
# |    fps              | 339      |
# |    time_elapsed     | 28708    |
# |    total_timesteps  | 9739140  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.32e-11 |
# |    n_updates        | 608690   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1448     |
# |    fps              | 339      |
# |    time_elapsed     | 28790    |
# |    total_timesteps  | 9766108  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.99e-11 |
# |    n_updates        | 610375   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1452     |
# |    fps              | 339      |
# |    time_elapsed     | 28870    |
# |    total_timesteps  | 9793084  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.42e-11 |
# |    n_updates        | 612061   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1456     |
# |    fps              | 339      |
# |    time_elapsed     | 28949    |
# |    total_timesteps  | 9820052  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.14e-10 |
# |    n_updates        | 613747   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1460     |
# |    fps              | 339      |
# |    time_elapsed     | 29028    |
# |    total_timesteps  | 9847016  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.86e-09 |
# |    n_updates        | 615432   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1464     |
# |    fps              | 339      |
# |    time_elapsed     | 29108    |
# |    total_timesteps  | 9873992  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.31e-10 |
# |    n_updates        | 617118   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1468     |
# |    fps              | 339      |
# |    time_elapsed     | 29188    |
# |    total_timesteps  | 9900972  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.84e-11 |
# |    n_updates        | 618804   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1472     |
# |    fps              | 339      |
# |    time_elapsed     | 29267    |
# |    total_timesteps  | 9927956  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46e-11 |
# |    n_updates        | 620491   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1476     |
# |    fps              | 339      |
# |    time_elapsed     | 29346    |
# |    total_timesteps  | 9954924  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.31e-12 |
# |    n_updates        | 622176   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.7e+04  |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1480     |
# |    fps              | 339      |
# |    time_elapsed     | 29426    |
# |    total_timesteps  | 9981900  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.99e-12 |
# |    n_updates        | 623862   |
# ----------------------------------
# Training phase completed!
# Time taken: 8:11:19
# Speed: 339.22 steps/second

# %%
env.close()
print("Environment closed.")
# Out:
# Environment closed.

# %%
# Save model to Google Drive
model.save("/content/drive/MyDrive/MECE689_Superman/models/dqn_baseline_10M")
print("Model saved to Google Drive")
# Out:
# Model saved to Google Drive

# %%
# Out:
# [Errno 2] No such file or directory: '/content/MECE689_Superman'
# /content
# total 16
# drwxr-xr-x 1 root root 4096 Sep 23 13:39 .
# drwxr-xr-x 1 root root 4096 Sep 25 14:20 ..
# drwxr-xr-x 4 root root 4096 Sep 23 13:39 .config
# drwxr-xr-x 1 root root 4096 Sep 23 13:39 sample_data
